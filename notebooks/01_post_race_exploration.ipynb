# %% [markdown]
# # PitWall-Predictor post-race exploration
# Run `python main.py` first to generate the offline synthetic CSV data.

# %%
from src.data_loader import load_all_data, get_race_laps
from src.driver_analysis import build_grid_summary
calendar, drivers, teams, laps = load_all_data()
barcelona = get_race_laps(laps, 'Barcelona-Catalunya Grand Prix')
summary, results = build_grid_summary(barcelona)
summary.head()
